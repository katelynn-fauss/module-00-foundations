# %%
import pandas as pd

sales_by_region = {
    "Region": ["North", "South", "East", "West", "Central"],
    "Revenue": [12000, 8500, 15400, 9800, 11200],
}

df = pd.DataFrame(sales_by_region)
df
# Out:
#     Region  Revenue
# 0    North    12000
# 1    South     8500
# 2     East    15400
# 3     West     9800
# 4  Central    11200

# %% [markdown]
# # My First Northstar Notebook
#
# This notebook is part of Lesson 0.4. It uses the `northstar` conda environment with Python 3.12.

# %%
print("Hello from the northstar environment.")
# Out:
# Hello from the northstar environment.
